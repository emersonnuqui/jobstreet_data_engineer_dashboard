# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv(r"C:\Users\Emerson\jobstreet_data_engineer_dashboard\data\jobstreet-2023-09-21.csv")

# %%
def clean_salary(salary):
    
    matches = re.findall(r"\d{1,3},\d{1,3}", str(salary))
    return int(matches[0].replace(",", "")) if matches else None

def clean_title(title):
    title = re.sub(r"""(urgent)|(hiring)|(night)|(shift)|(mid)|(morning)|(graveyard)|(gy)|(dayshift)|(set)|(asap)|(set up)|(day)|(temporary)|(work)|(from)|(home)|(wfh)|(temp)|(office)|(onsite)|(hybrid)|([-*!\[\]|:;])""", "", title, flags=re.IGNORECASE)
    
    matches = re.split(r'\s[,*/\[\]\(\)|]|(\s{2,})', str(title))
    matches = [x for x in matches if x is not None]                                      #Removing None type
    #matches = [text for text in matches if all(word.isalpha() for word in text.split())] #Removing Spaces
    matches = [text for text in matches if text.strip()]                                 
    return matches[0].strip() if matches else None

def clean_year_of_experience(experience):
    if isinstance(experience, str):
        matches = re.findall(r"\d{1,2}", experience)
        return matches[0] if matches else None
    else:
        return None  # or any other value you prefer for non-string cases

def clean_num_of_employees(employees):
    if isinstance(employees, str):
        text = re.sub("(\sEmployees)|(\semployees)|(\sEmployee)|(\semployee)", "", employees)
        return text
    else:
        return None
    
def clean_qualification(df):
    df['Qualification'] = df['Qualification'].replace({'Not Specified': None})
    return df

def clean_data(df):
    df = df[["job_id", "title", "location", "company",
            "salary", "summary", "job_url", "Qualification",
            "Years of Experience", "Job Type", "Company Size"]]
    #df['title'] = df['title'].map(clean_title)
    df['salary'] = df['salary'].map(clean_salary)
    df['Years of Experience'] = df['Years of Experience'].map(clean_year_of_experience)
    df['Company Size'] = df['Company Size'].map(clean_num_of_employees)
    df = clean_qualification(df)
    return df

# %%
clean_data = clean_data(data)
display(clean_data)
# Out:
# C:\Users\Emerson\AppData\Local\Temp\ipykernel_5144\1066994271.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['salary'] = df['salary'].map(clean_salary)
# C:\Users\Emerson\AppData\Local\Temp\ipykernel_5144\1066994271.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Years of Experience'] = df['Years of Experience'].map(clean_year_of_experience)
# C:\Users\Emerson\AppData\Local\Temp\ipykernel_5144\1066994271.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company Size'] = df['Company Size'].map(clean_num_of_employees)
# C:\Users\Emerson\AppData\Local\Temp\ipykernel_5144\1066994271.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Qualification'] = df['Qualification'].replace({'Not Specified': None})
#        job_id                                              title  \
# 0    13228347                             Data Engineer - Cavite
# 1    13235504                            Snowflake Data Engineer
# 2    13235181                      Data Engineer: Data Warehouse
# 3    13233993  Senior Data Engineer (Data Developer - Databri...
# 4    13234232                                     Data Scientist
# ..        ...                                                ...
# 738  10368923                           Multi-skilled Technician
# 739  10368209                               Accountant - Payroll
# 740  10368757                          Senior NetSuite Developer
# 741  10367679       Team Leader Product Environmental Compliance
# 742  10367682                              Business Analyst, GTM
#
#                     location                                      company  \
# 0                Taguig City                           Schneider Electric
# 1    Multiple work locations                                    Accenture
# 2                Quezon City  Collabera Technologies Private Limited Inc.
# 3                Makati City                               Carenet Health
# 4            Muntinlupa City          Primover Consultancy Services, Inc.
# ..                       ...                                          ...
# 738     National Capital Reg              Jones Lang LaSalle Phils., Inc.
# 739     National Capital Reg                               First Datacorp
# 740              Makati City                                       Kraken
# 741  Multiple work locations              Emerson Electric Asia Ltd. ROHQ
# 742     National Capital Reg                                  RingCentral
#
#       salary                                            summary  \
# 0    70000.0  Great People make Schneider Electric a great c...
# 1        NaN  Ready to become part of the dynamic Accenture ...
# 2        NaN  Job Description:\n•Perform requirements identi...
# 3        NaN  We are taking our growing Business Intelligenc...
# 4        NaN  Job Qualifications\nMid- Level\nBachelor’s deg...
# ..       ...                                                ...
# 738      NaN  JLL supports the Whole You, personally and pro...
# 739      NaN  Our purpose\nHere at Datacom, we connect peopl...
# 740      NaN  Building the Future of Crypto \nOur Krakenites...
# 741      NaN  Emerson’s 130 years of history has been filled...
# 742      NaN  S ay hello to possibilities at Acquire Asia Pa...
#
#                                                job_url  \
# 0    https://www.jobstreet.com.ph/en/job/data-engin...
# 1    https://www.jobstreet.com.ph/en/job/snowflake-...
# 2    https://www.jobstreet.com.ph/en/job/data-engin...
# 3    https://www.jobstreet.com.ph/en/job/senior-dat...
# 4    https://www.jobstreet.com.ph/en/job/data-scien...
# ..                                                 ...
# 738  https://www.jobstreet.com.ph/en/job/multi-skil...
# 739  https://www.jobstreet.com.ph/en/job/accountant...
# 740  https://www.jobstreet.com.ph/en/job/senior-net...
# 741  https://www.jobstreet.com.ph/en/job/team-leade...
# 742  https://www.jobstreet.com.ph/en/job/business-a...
#
#                                          Qualification Years of Experience  \
# 0                                                 None                   3
# 1    Bachelor's/College Degree, Post Graduate Diplo...                   3
# 2                            Bachelor's/College Degree                   3
# 3                            Bachelor's/College Degree                   7
# 4                                                 None                   2
# ..                                                 ...                 ...
# 738                                               None                None
# 739                                               None                None
# 740                                               None                None
# 741                                               None                None
# 742                                               None                None
#
#       Job Type    Company Size
# 0    Full-Time  More than 5000
# 1    Full-Time  More than 5000
# 2    Full-Time  More than 5000
# 3    Full-Time     1001 - 2000
# 4    Full-Time       201 - 500
# ..         ...             ...
# 738  Full-Time     2001 - 5000
# 739        NaN        51 - 200
# 740  Full-Time            None
# 741        NaN     2001 - 5000
# 742        NaN      501 - 1000
#
# [743 rows x 11 columns]
